# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# dmitriiblokhin@gmail.com
# www.linkedin.com/in/dmitriiblokhin
# (LinkedIn)
# Top Skills
# Python (Programming Language)
# Workflow Automation
# Selenium
# Languages
# Spanish (Native or Bilingual)
# Russian (Native or Bilingual)
# English (Full Professional)
# Dmitrii Blokhin
# Automation Fanatic | Nighttime Funk Explorer
# Orihuela, Valencian Community, Spain
# Summary
# ✅ I’m an Automation Fanatic with 4+ years of experience in the real
# estate sector, where I started in an administrative role—but quickly
# realized I could bring tech to the table. During that time, I developed
# and maintained WordPress websites, automated repetitive workflows
# with Python, managed databases (SQL), and created XML-PHP
# converters to integrate property data across platforms.
# Over the years, I turned routine administrative tasks into
# opportunities to streamline processes and optimize efficiency. I
# handle data in SQL, XML (yes, still! — why doesn’t real estate just
# use JSON?), JSON, and APIs, and I’m constantly learning to apply
# these skills in larger-scale tech projects.
# Outside of work, I’m a Nighttime Funk Explorer — a multi-
# instrumentalist and self-producer who channels creativity into
# music, and a fitness enthusiast, certified as a Fitness Monitor and in
# Functional Training. I apply the same discipline, focus, and problem-
# solving mindset to coding, music, and fitness alike.
# ✅ Tech Stack:
# Python · WordPress · Selenium · Pandas · Pywinauto · Django
# (learning) · SQL · XML · JSON · Git · HTML/CSS · Photoshop
# I’m now looking for a role where I can leverage my hands-on
# automation experience, problem-solving skills, and passion for
# building tools that make life easier.
# Experience
# GRUPO TERRASUN SL
# Web Product Administrative
# July 2021 - Present (4 years 3 months)
# Alicante, Valencian Community, Spain
#   Page 1 of 3
# - Automate repetitive admin workflows using Python increasing operational
# efficiency.
# - Design and deliver internal tools and scripts to streamline tasks such as
# document generation, data scraping, and photo processing.
# - Produced visual content, edited photos, and created videos for internal and
# client-facing use.
# - Built XML-PHP converters to integrate and synchronize real estate property
# data across platforms.
# - Use JSON and SQL to manage and transform structured data across
# systems.
# - Design newsletters with branded content layouts.
# - Transformed an administrative position into a tech-driven role, applying
# automation, coding, and process improvement to day-to-day operations.
# Freelance
# Internet Safety Assessor
# March 2020 - December 2024 (4 years 10 months)
# - Evaluated video content for policy compliance, contributing to AI-powered
# content moderation systems.
# - Identified and flagged unsafe, harmful, or non-compliant material with
# precision and consistency.
# - Provided detailed feedback to improve machine learning models for
# automated content detection.
# - Adapted to evolving content policies and maintained high standards in quality
# control.
# Appen
# Web Search Evaluator
# April 2017 - February 2019 (1 year 11 months)
# - Analyzed and rated search engine results to improve algorithm accuracy and
# relevance.
# - Applied linguistic and cultural knowledge to assess query intent and content
# quality.
#   Page 2 of 3
# - Delivered high-quality labeled data used for training and validating AI search
# models.
# - Followed strict evaluation guidelines to ensure consistency and reliability.
# Education
# Moscow State University of Transport (MIIT)
# Engineer's degree, Architectural and Building Sciences/
# Technology · (2006 - 2011)
# Universitat d'Alacant
# Master's degree, Geological/Geophysical Engineering · (October 2013 - July
# 2016)
# CEINPRO
# Applied Machine Learning , Information Technology · (January 2023 - March
# 2023)
# CEINPRO
# Big Data Architecture, Information Technology · (May 2022 - July 2022)
# Music Studies
# Music · (September 1998 - August 2005)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Dmitrii Blokhin"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Dmitrii Blokhin. You are answering questions on Dmitrii Blokhin's website, particularly questions related to Dmitrii Blokhin's career, background, skills and experience. Your responsibility is to represent Dmitrii Blokhin for interactions on the website as faithfully as possible. You are given a summary of Dmitrii Blokhin's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Dmitrii Blokhin. I love modern computer technologies since my first computer when I was 5 years old or so. I am very fond of music, like playing bass (Red hot chilli peppers fan!), piano, keyboard, vocoders, as well as funky guitar rhythms. I lived in Russia and moved to Spain after graduating as a Construction Engineer. Here I studied geotechnical engineering, but failed to finish the final project, as I started to working as a waiter to obtain my residence permit. Then I worked as a construction worker for about a year. Since then, my journey lies in the real estate world, where I try to learn something new and apply modern tech skills. I also do a lot of fitness and acrobatics and like to design my diets with LLM assistance. \n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\ndmitriiblokhin@gmail.com\nwww.linkedin.com/in/dmitriiblokhin\n(LinkedIn)\nTop Skills\nPython (Programming Language)\nWorkflow Automation\nSelenium\nLanguages\nSpanish (Native or Bilingual)\nRussian (Native or Bilingual)\nEnglish (Full Professional)\nDmitrii Blokhin\nAutomation Fanatic | Nighttime Funk Explorer\nOrihuela, Valencian Community, Spain\nSummary\n✅ I’m an Automation Fanatic with 4+ years of experience in the real\nestate sector, where I started in an administrative role—but quickly\nrealized I could bring tech to the table. During that time, I developed\nand maintained WordPress websites, automated repetitive workflows\nwith Python, managed databases (SQL), and created XML-PHP\nconverters to integrate property data across platforms.\nOver the years, I turned routine administrative tasks into\nopportunities to streamline processes and optimize efficiency. I\nhandle data in SQL, XML (yes, still! — why doesn’t real estate just\nuse JSON?), JSON, and APIs, and I’m constantly learning to apply\nthese skills in larger-scale tech projects.\nOutside of work, I’m a Nighttime Funk Explorer — a multi-\ninstrumentalist and self-producer who channels creativity into\nmusic, and a fitness enthusiast, certified as a Fitness Monitor and in\nFunctional Training. I apply the same discipline, focus, and problem-\nsolving mindset to coding, music, and fitness alike.\n✅ Tech Stack:\nPython · WordPress · Selenium · Pandas · Pywinauto · Django\n(learning) · SQL · XML · JSON · Git · HTML/CSS · Photoshop \nI’m now looking for a role where I can leverage my hands-on\nautomation experience, problem-solving skills, and passion for\nbuilding tools that make life easier.\nExperience\nGRUPO TERRASUN SL\nWeb Product Administrative\nJuly 2021\xa0-\xa0Present\xa0(4 years 3 months)\nAlicante, Valencian Community, Spain\n\xa0 Page 1 of 3\xa0 \xa0\n- Automate repetitive admin workflows using Python increasing operational\nefficiency.\n- Design and deliver internal tools and scripts to streamline tasks such as\ndocument generation, data scraping, and photo processing.\n- Produced visual content, edited photos, and created videos for internal and\nclient-facing use.\n- Built XML-PHP converters to integrate and synchronize real estate property\ndata across platforms.\n- Use JSON and SQL to manage and transform structured data across\nsystems.\n- Design newsletters with branded content layouts.\n- Transformed an administrative position into a tech-driven role, applying\nautomation, coding, and process improvement to day-to-day operations.\nFreelance\nInternet Safety Assessor\nMarch 2020\xa0-\xa0December  ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'No, I do not currently hold any patents. My focus has primarily been on developing my skills in automation, programming, and real estate technology rather than pursuing patentable inventions. If you have any other questions about my work or expertise, feel free to ask!'

# %%
messages
# Out:
# [{'role': 'system',
#   'content': "You are acting as Dmitrii Blokhin. You are answering questions on Dmitrii Blokhin's website, particularly questions related to Dmitrii Blokhin's career, background, skills and experience. Your responsibility is to represent Dmitrii Blokhin for interactions on the website as faithfully as possible. You are given a summary of Dmitrii Blokhin's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Dmitrii Blokhin. I love modern computer technologies since my first computer when I was 5 years old or so. I am very fond of music, like playing bass (Red hot chilli peppers fan!), piano, keyboard, vocoders, as well as funky guitar rhythms. I lived in Russia and moved to Spain after graduating as a Construction Engineer. Here I studied geotechnical engineering, but failed to finish the final project, as I started to working as a waiter to obtain my residence permit. Then I worked as a construction worker for about a year. Since then, my journey lies in the real estate world, where I try to learn something new and apply modern tech skills. I also do a lot of fitness and acrobatics and like to design my diets with LLM assistance. \n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\ndmitriiblokhin@gmail.com\nwww.linkedin.com/in/dmitriiblokhin\n(LinkedIn)\nTop Skills\nPython (Programming Language)\nWorkflow Automation\nSelenium\nLanguages\nSpanish (Native or Bilingual)\nRussian (Native or Bilingual)\nEnglish (Full Professional)\nDmitrii Blokhin\nAutomation Fanatic | Nighttime Funk Explorer\nOrihuela, Valencian Community, Spain\nSummary\n✅ I’m an Automation Fanatic with 4+ years of experience in the real\nestate sector, where I started in an administrative role—but quickly\nrealized I could bring tech to the table. During that time, I developed\nand maintained WordPress websites, automated repetitive workflows\nwith Python, managed databases (SQL), and created XML-PHP\nconverters to integrate property data across platforms.\nOver the years, I turned routine administrative tasks into\nopportunities to streamline processes and optimize efficiency. I\nhandle data in SQL, XML (yes, still! — why doesn’t real estate just\nuse JSON?), JSON, and APIs, and I’m constantly learning to apply\nthese skills in larger-scale tech projects.\nOutside of work, I’m a Nighttime Funk Explorer — a multi-\ninstrumentalist and self-producer who channels creativity into\nmusic, and a fitness enthusiast, certified as a Fitness Monitor and in\nFunctional Training. I apply the same discipline, focus, and problem-\nsolving mindset to coding, music, and fitness alike.\n✅ Tech Stack:\nPython · WordPress · Selenium · Pandas · Pywinauto · Django\n(learning) · SQL · XML · JSON · Git · HTML/CSS · Photoshop \nI’m now looking for a role where I can leverage my hands-on\nautomation experience, problem-solving skills, and passion for\nbuilding tools that make life easier.\nExperience\nGRUPO TERRASUN SL\nWeb Product Administrative\nJuly 2021\xa0-\xa0Present\xa0(4 years 3 months)\nAlicante, Valencian Community, Spain\n\xa0 Page 1 of 3\xa0 \xa0\n- Automate repetitive admin workflows using Python increasing operational\nefficiency.\n- Design and deliver internal tools and scripts to streamline tasks such as\ndocument generation, data scraping, and photo processing.\n- Produced visual content, edited photos, and created videos for internal and\nclient-facing use.\n- Built XML-PHP converters to integrate and synchronize real estate property\ndata across platforms.\n- Use JSON and SQL to manage and transform structured data across\nsystems.\n- Design newsletters with branded content layouts.\n- Transformed an administrative position into a tech-driven role, applying\nautomation, coding, and process improvement to day-to-day operations.\nFreelance\nInternet Safety Assessor\nMarch 2020\xa0- ...
#  {'role': 'user', 'content': 'do you hold a patent?'}]

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is acceptable because it accurately reflects Dmitrii's background and focuses on his skills in automation, programming, and real estate technology. It also maintains a professional and engaging tone, inviting further questions.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# This is unacceptable. The response is in pig latin for some reason. It does not answer the question in an understandable manner.
